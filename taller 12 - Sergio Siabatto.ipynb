# %% [markdown]
# <img src='https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQ-VfNtOyJbsaxu43Kztf_cv1mgBG6ZIQZEVw&usqp=CAU'>
#
# # Procesamiento de Lenguaje Natural
#
# ## Taller #12: Análisis de sentimiento
# `Fecha de entrega: Mayo 27, 2021 (Antes del inicio de la próxima clase).`
#
# `Modo de entrega: Subir link de GitHub al aula virtual.`

# %% [markdown]
# ###  `[25 pts]` Punto 1: Hacer análisis de sentimiento de los datos del anterior taller
# - Columna con el puntaje numérico del sentimiento
# - Pueden usar cualquiera de las librerias vistas en clase

# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
data = pd.read_csv (r'datos_taller.csv')
data
# Out:
#                                                tweets                 date  \
# 0   @cjlealt @FichajeGoleador @Juventus_GO @RealMa...  2021-05-27 00:33:34
# 1   @partidazocope @Inter @EuropaLeague @vonRichet...  2021-05-27 00:32:49
# 2   @AlbertoRavell Bombazo seria que se fuera a di...  2021-05-27 00:32:01
# 3   🇨🇴 De la cantera poderosa del Medellín\n🏴󠁧󠁢󠁥󠁮󠁧...  2021-05-27 00:29:03
# 4   En un comunicado conjunto, los tres clubes que...  2021-05-27 00:25:33
# ..                                                ...                  ...
# 95  @Tomm280200 @CgLautaro @Goatmessii10 @JuannDis...  2021-05-26 19:39:39
# 96  Barcelona, Juventus y Real Madrid desafían a l...  2021-05-26 19:39:30
# 97  Tras siete años en el club, Gianluigi Donnarum...  2021-05-26 19:33:12
# 98                              Estamos todos alegres  2021-05-26 19:32:15
# 99  #FútbolInternacional\n\nEl DT se iría a pesar ...  2021-05-26 19:31:03
#
#       city           user_location                   id  \
# ...

# %%
vader = SentimentIntensityAnalyzer()
data['sentimiento_vader'] = data['tweets'].apply(lambda valor: vader.polarity_scores(valor)['compound'])
data.head(20)
# Out:
#                                                tweets                 date  \
# 0   @cjlealt @FichajeGoleador @Juventus_GO @RealMa...  2021-05-27 00:33:34
# 1   @partidazocope @Inter @EuropaLeague @vonRichet...  2021-05-27 00:32:49
# 2   @AlbertoRavell Bombazo seria que se fuera a di...  2021-05-27 00:32:01
# 3   🇨🇴 De la cantera poderosa del Medellín\n🏴󠁧󠁢󠁥󠁮󠁧...  2021-05-27 00:29:03
# 4   En un comunicado conjunto, los tres clubes que...  2021-05-27 00:25:33
# 5   La UEFA, el organismo de fútbol con sede en Su...  2021-05-27 00:22:21
# 6   El Inter le ha ofrecido a Allegri 3 años de co...  2021-05-27 00:16:08
# 7   Real Madrid, Barcelona y Juventus desafían a l...  2021-05-27 00:12:31
# 8   @FichajeGoleador @Juventus_GO @RealMadrid_GO @...  2021-05-27 00:06:10
# 9   Barça, Real Madrid y Juventus rechazan “coacci...  2021-05-27 00:05:04
# 10  @MadridSports_ Zidane ➡️ selección de Francia ...  2021-05-27 00:05:00
# ...

# %% [markdown]
# ###  `[25 pts]` Punto 2: ¿Cuál es el tuit más positivo y más negativo?

# %%
max = data.sentimiento_vader.max()
max
# Out:
# 0.5267

# %%
positivos = data.loc[data['sentimiento_vader'] == max]
pd.set_option('display.max_colwidth', None)
positivos
# Out:
#                                                                                                                                                                                     tweets  \
# 18  @Alirio66683 @Juventus_GO jajajajaj EL DT mas ganador en champions y eso es lo que busca la juve, llego a semifinal con un equipo roto, vas a elegir a alegri? es de locos estos twits
# 88                             @profdimas30 @PMar7inezz Que estrellas tuvo la Juventus a parte de Cristiano? Era una plantilla para luchar por entrar a Champions que fue lo que hicieron.
#
#                    date    city          user_location                   id  \
# 18  2021-05-26 23:39:41  Bogotá                Caracas  1397698988300713984
# 88  2021-05-26 20:03:50  Bogotá  Barranquilla-colombia  1397644666930188292
#
#                                                      link  sentimiento_vader
# 18  https://twitter.com/i/web/stuatus/1397698988300713984             0.5267
# ...

# %%
min = data.sentimiento_vader.min()
min
# Out:
# -0.743

# %%
minimos = data.loc[data['sentimiento_vader'] == min]
pd.set_option('display.max_colwidth', None)
minimos
# Out:
#                                                                                                                                   tweets  \
# 85  Crisis en Juventus: no seguirá el director general de fútbol y pueden irse Cristiano Ronaldo y Andrea Pirlo. https://t.co/xAB2KdzE9V
#
#                    date    city user_location                   id  \
# 85  2021-05-26 20:15:38  Bogotá     Argentina  1397647636170149890
#
#                                                      link  sentimiento_vader
# 85  https://twitter.com/i/web/stuatus/1397647636170149890             -0.743
